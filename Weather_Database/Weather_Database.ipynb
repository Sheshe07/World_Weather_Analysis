# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# 4. Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Import the API key.
from config import weather_api_key

# %%
# 5. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# 6.Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)
city_data = []

# Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdesc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_wdesc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lorengau
# Processing Record 2 of Set 1 | nantucket
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | urumqi
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | najran
# Processing Record 8 of Set 1 | port moresby
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | tinskoy
# Processing Record 12 of Set 1 | ahuimanu
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | chilca
# Processing Record 16 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | isangel
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | kpandae
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | san patricio
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | westerland
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | kununurra
# Processing Record 30 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 1 | tiszafured
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | kargasok
# Processing Record 34 of Set 1 | sao filipe
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | sao joao da barra
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | bay roberts
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | mbaiki
# Processing Record 43 of Set 1 | egvekinot
# Processing Record 44 of Set 1 | agadez
# Processing Record 45 of Set 1 | sao jose de ribamar
# Processing Record 46 of Set 1 | andenes
# Processing Record 47 of Set 1 | shache
# Processing Record 48 of Set 1 | strelka
# Processing Record 49 of Set 1 | hirara
# Processing Record 50 of Set 1 | miyako
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | oranjemund
# Processing Record 3 of Set 2 | aklavik
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | codrington
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | alice springs
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | oktyabrskiy
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | wakkanai
# Processing Record 14 of Set 2 | kurmanayevka
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | luena
# Processing Record 18 of Set 2 | beringovskiy
# Processing Record 19 of Set 2 | kayerkan
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 2 | katsuura
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | half moon bay
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | yakima
# Processing Record 28 of Set 2 | bengkalis
# City not found. Skipping...
# Processing Record 29 of Set 2 | mehamn
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | dunedin
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | umm lajj
# Processing Record 35 of Set 2 | tessalit
# Processing Record 36 of Set 2 | mercedes
# Processing Record 37 of Set 2 | baoro
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | touros
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | vostok
# Processing Record 43 of Set 2 | tongchuan
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | nam phong
# Processing Record 48 of Set 2 | polovinnoye
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | opuwo
# Processing Record 1 of Set 3 | sandwick
# Processing Record 2 of Set 3 | roald
# Processing Record 3 of Set 3 | mocuba
# Processing Record 4 of Set 3 | yar-sale
# Processing Record 5 of Set 3 | barranca
# Processing Record 6 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | wanning
# Processing Record 9 of Set 3 | bom jesus
# Processing Record 10 of Set 3 | sayyan
# Processing Record 11 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | george town
# Processing Record 16 of Set 3 | sao jose da coroa grande
# Processing Record 17 of Set 3 | saint-joseph
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | mount gambier
# Processing Record 20 of Set 3 | cayenne
# Processing Record 21 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 3 | raga
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | rikitea
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | coahuayana
# Processing Record 27 of Set 3 | mgandu
# Processing Record 28 of Set 3 | chapais
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | ahipara
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | divnomorskoye
# Processing Record 34 of Set 3 | haines junction
# Processing Record 35 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | port hedland
# Processing Record 38 of Set 3 | saint-philippe
# Processing Record 39 of Set 3 | novovasylivka
# Processing Record 40 of Set 3 | bubaque
# Processing Record 41 of Set 3 | carnarvon
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 3 | ulyanovka
# Processing Record 45 of Set 3 | saint-ambroise
# Processing Record 46 of Set 3 | alamosa
# Processing Record 47 of Set 3 | hay river
# Processing Record 48 of Set 3 | okha
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | port lincoln
# Processing Record 1 of Set 4 | avera
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | dwarka
# Processing Record 4 of Set 4 | college
# Processing Record 5 of Set 4 | anadyr
# Processing Record 6 of Set 4 | padang
# Processing Record 7 of Set 4 | camacupa
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 4 | cadillac
# Processing Record 11 of Set 4 | tokamachi
# Processing Record 12 of Set 4 | mbuji-mayi
# Processing Record 13 of Set 4 | hambantota
# Processing Record 14 of Set 4 | monte gordo
# Processing Record 15 of Set 4 | kaitangata
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | hwange
# Processing Record 18 of Set 4 | the pas
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | neyshabur
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | moen
# Processing Record 23 of Set 4 | pathein
# Processing Record 24 of Set 4 | comodoro rivadavia
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | liku
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | northam
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | lensk
# Processing Record 31 of Set 4 | sibu
# Processing Record 32 of Set 4 | merritt island
# Processing Record 33 of Set 4 | sahuaripa
# Processing Record 34 of Set 4 | joshimath
# Processing Record 35 of Set 4 | copiapo
# Processing Record 36 of Set 4 | la ronge
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | flinders
# Processing Record 39 of Set 4 | quatre cocos
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | tambopata
# Processing Record 42 of Set 4 | jalu
# Processing Record 43 of Set 4 | puerto colombia
# Processing Record 44 of Set 4 | sovetskoye
# Processing Record 45 of Set 4 | khatanga
# Processing Record 46 of Set 4 | vanavara
# Processing Record 47 of Set 4 | madang
# Processing Record 48 of Set 4 | cidreira
# Processing Record 49 of Set 4 | muros
# Processing Record 50 of Set 4 | znamensk
# Processing Record 1 of Set 5 | tambura
# Processing Record 2 of Set 5 | maceio
# Processing Record 3 of Set 5 | sorland
# Processing Record 4 of Set 5 | nueva gerona
# Processing Record 5 of Set 5 | prince rupert
# Processing Record 6 of Set 5 | thompson
# Processing Record 7 of Set 5 | pangnirtung
# Processing Record 8 of Set 5 | tuatapere
# Processing Record 9 of Set 5 | piraju
# Processing Record 10 of Set 5 | hami
# Processing Record 11 of Set 5 | znamenskoye
# Processing Record 12 of Set 5 | mbekenyera
# Processing Record 13 of Set 5 | kavieng
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | marienburg
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | buin
# Processing Record 18 of Set 5 | north platte
# Processing Record 19 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 5 | manakara
# Processing Record 21 of Set 5 | lamu
# Processing Record 22 of Set 5 | conceicao do araguaia
# Processing Record 23 of Set 5 | rebrikha
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | russell
# Processing Record 26 of Set 5 | chipinge
# Processing Record 27 of Set 5 | carutapera
# Processing Record 28 of Set 5 | torrevieja
# Processing Record 29 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | doha
# Processing Record 31 of Set 5 | taoudenni
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 5 | juanjui
# Processing Record 35 of Set 5 | rincon
# Processing Record 36 of Set 5 | awjilah
# Processing Record 37 of Set 5 | madoc
# Processing Record 38 of Set 5 | tuktoyaktuk
# Processing Record 39 of Set 5 | geilo
# Processing Record 40 of Set 5 | guanica
# Processing Record 41 of Set 5 | barrow
# Processing Record 42 of Set 5 | aktau
# Processing Record 43 of Set 5 | bronnoysund
# Processing Record 44 of Set 5 | manono
# Processing Record 45 of Set 5 | mahon
# Processing Record 46 of Set 5 | zgierz
# Processing Record 47 of Set 5 | saint-augustin
# Processing Record 48 of Set 5 | poso
# Processing Record 49 of Set 5 | ulaangom
# Processing Record 50 of Set 5 | castelo do piaui
# Processing Record 1 of Set 6 | kaspiyskiy
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | pooler
# Processing Record 4 of Set 6 | luderitz
# Processing Record 5 of Set 6 | punta cardon
# Processing Record 6 of Set 6 | angoche
# Processing Record 7 of Set 6 | staraya toropa
# Processing Record 8 of Set 6 | kysyl-syr
# Processing Record 9 of Set 6 | labuhan
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | ucluelet
# Processing Record 12 of Set 6 | alexandria
# Processing Record 13 of Set 6 | areka
# Processing Record 14 of Set 6 | tingi
# Processing Record 15 of Set 6 | kodiak
# Processing Record 16 of Set 6 | majur
# Processing Record 17 of Set 6 | narsaq
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | margate
# Processing Record 20 of Set 6 | saldanha
# Processing Record 21 of Set 6 | ercis
# Processing Record 22 of Set 6 | fengzhen
# Processing Record 23 of Set 6 | rapid valley
# Processing Record 24 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 6 | tazovskiy
# Processing Record 26 of Set 6 | mount isa
# Processing Record 27 of Set 6 | kuremaa
# Processing Record 28 of Set 6 | westport
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | raudeberg
# Processing Record 31 of Set 6 | san pedro
# Processing Record 32 of Set 6 | gualaquiza
# Processing Record 33 of Set 6 | santa maria
# Processing Record 34 of Set 6 | kishtwar
# Processing Record 35 of Set 6 | tres arroyos
# Processing Record 36 of Set 6 | asau
# Processing Record 37 of Set 6 | atambua
# Processing Record 38 of Set 6 | bonavista
# Processing Record 39 of Set 6 | waihi
# Processing Record 40 of Set 6 | murdochville
# Processing Record 41 of Set 6 | thinadhoo
# Processing Record 42 of Set 6 | burica
# City not found. Skipping...
# Processing Record 43 of Set 6 | chor
# Processing Record 44 of Set 6 | topolovgrad
# Processing Record 45 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 6 | watertown
# Processing Record 47 of Set 6 | lana
# Processing Record 48 of Set 6 | brookhaven
# Processing Record 49 of Set 6 | lavrentiya
# Processing Record 50 of Set 6 | tura
# Processing Record 1 of Set 7 | khilok
# Processing Record 2 of Set 7 | qaanaaq
# Processing Record 3 of Set 7 | henties bay
# Processing Record 4 of Set 7 | san carlos de bariloche
# Processing Record 5 of Set 7 | urubamba
# Processing Record 6 of Set 7 | palmerston
# Processing Record 7 of Set 7 | baykit
# Processing Record 8 of Set 7 | nizhniy kuranakh
# Processing Record 9 of Set 7 | qasigiannguit
# Processing Record 10 of Set 7 | bilibino
# Processing Record 11 of Set 7 | khani
# Processing Record 12 of Set 7 | camana
# Processing Record 13 of Set 7 | swan hill
# Processing Record 14 of Set 7 | svetlogorsk
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | ranfurly
# Processing Record 17 of Set 7 | ermelo
# Processing Record 18 of Set 7 | bonfim
# Processing Record 19 of Set 7 | huancavelica
# Processing Record 20 of Set 7 | mitu
# Processing Record 21 of Set 7 | bilma
# Processing Record 22 of Set 7 | ornskoldsvik
# Processing Record 23 of Set 7 | bandarbeyla
# Processing Record 24 of Set 7 | nieuw nickerie
# Processing Record 25 of Set 7 | katherine
# Processing Record 26 of Set 7 | tatarskaya pishlya
# Processing Record 27 of Set 7 | ayr
# Processing Record 28 of Set 7 | gladstone
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | camopi
# Processing Record 31 of Set 7 | samdrup jongkhar
# Processing Record 32 of Set 7 | sambava
# Processing Record 33 of Set 7 | zarumilla
# Processing Record 34 of Set 7 | glace bay
# Processing Record 35 of Set 7 | tevaitoa
# Processing Record 36 of Set 7 | gat
# Processing Record 37 of Set 7 | terney
# Processing Record 38 of Set 7 | moranbah
# Processing Record 39 of Set 7 | sharjah
# Processing Record 40 of Set 7 | ambon
# Processing Record 41 of Set 7 | knysna
# Processing Record 42 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 7 | antalaha
# Processing Record 44 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 7 | flin flon
# Processing Record 46 of Set 7 | leo
# Processing Record 47 of Set 7 | klyuchi
# Processing Record 48 of Set 7 | pedasi
# Processing Record 49 of Set 7 | porto novo
# Processing Record 50 of Set 7 | kudahuvadhoo
# Processing Record 1 of Set 8 | tottori
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | batticaloa
# Processing Record 4 of Set 8 | souillac
# Processing Record 5 of Set 8 | birjand
# Processing Record 6 of Set 8 | dingle
# Processing Record 7 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 8 of Set 8 | sinnamary
# Processing Record 9 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 8 | bethel
# Processing Record 11 of Set 8 | gao
# Processing Record 12 of Set 8 | shenjiamen
# Processing Record 13 of Set 8 | tasiilaq
# Processing Record 14 of Set 8 | kingsport
# Processing Record 15 of Set 8 | vaasa
# Processing Record 16 of Set 8 | sitka
# Processing Record 17 of Set 8 | dubti
# Processing Record 18 of Set 8 | cheyur
# City not found. Skipping...
# Processing Record 19 of Set 8 | phan thiet
# Processing Record 20 of Set 8 | salinopolis
# Processing Record 21 of Set 8 | muromtsevo
# Processing Record 22 of Set 8 | chokurdakh
# Processing Record 23 of Set 8 | ukiah
# Processing Record 24 of Set 8 | lata
# Processing Record 25 of Set 8 | turukhansk
# Processing Record 26 of Set 8 | san borja
# Processing Record 27 of Set 8 | pendleton
# Processing Record 28 of Set 8 | makung
# City not found. Skipping...
# Processing Record 29 of Set 8 | mzimba
# Processing Record 30 of Set 8 | shelburne
# Processing Record 31 of Set 8 | neuquen
# Processing Record 32 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 8 | constitucion
# Processing Record 34 of Set 8 | kattivakkam
# Processing Record 35 of Set 8 | boddam
# Processing Record 36 of Set 8 | aransas pass
# Processing Record 37 of Set 8 | khandyga
# Processing Record 38 of Set 8 | tiko
# Processing Record 39 of Set 8 | tilichiki
# Processing Record 40 of Set 8 | dikson
# Processing Record 41 of Set 8 | bodden town
# Processing Record 42 of Set 8 | kikwit
# Processing Record 43 of Set 8 | craig
# Processing Record 44 of Set 8 | berdsk
# Processing Record 45 of Set 8 | vitim
# Processing Record 46 of Set 8 | coatzacoalcos
# Processing Record 47 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 8 | laurinburg
# Processing Record 49 of Set 8 | launceston
# Processing Record 50 of Set 8 | seoul
# Processing Record 1 of Set 9 | san antonio
# Processing Record 2 of Set 9 | tigil
# Processing Record 3 of Set 9 | galle
# Processing Record 4 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 9 | lucea
# Processing Record 6 of Set 9 | birao
# Processing Record 7 of Set 9 | sandpoint
# Processing Record 8 of Set 9 | cabo san lucas
# Processing Record 9 of Set 9 | puerto madryn
# Processing Record 10 of Set 9 | port-gentil
# Processing Record 11 of Set 9 | nelson bay
# Processing Record 12 of Set 9 | kinablangan
# Processing Record 13 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 14 of Set 9 | te anau
# Processing Record 15 of Set 9 | lompoc
# Processing Record 16 of Set 9 | bairiki
# Processing Record 17 of Set 9 | kahului
# Processing Record 18 of Set 9 | alta floresta
# Processing Record 19 of Set 9 | hamilton
# Processing Record 20 of Set 9 | honiara
# Processing Record 21 of Set 9 | ouango
# Processing Record 22 of Set 9 | syke
# Processing Record 23 of Set 9 | apache junction
# Processing Record 24 of Set 9 | ende
# Processing Record 25 of Set 9 | arman
# Processing Record 26 of Set 9 | jining
# Processing Record 27 of Set 9 | springbok
# Processing Record 28 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 9 | marsa matruh
# Processing Record 30 of Set 9 | alvaraes
# Processing Record 31 of Set 9 | artigas
# Processing Record 32 of Set 9 | dickinson
# Processing Record 33 of Set 9 | alofi
# Processing Record 34 of Set 9 | vila velha
# Processing Record 35 of Set 9 | poum
# Processing Record 36 of Set 9 | voyvozh
# Processing Record 37 of Set 9 | matagami
# Processing Record 38 of Set 9 | bhimunipatnam
# Processing Record 39 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 9 | savelugu
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | port blair
# Processing Record 43 of Set 9 | japura
# Processing Record 44 of Set 9 | konin
# Processing Record 45 of Set 9 | sun city west
# Processing Record 46 of Set 9 | marystown
# Processing Record 47 of Set 9 | nenjiang
# Processing Record 48 of Set 9 | makakilo city
# Processing Record 49 of Set 9 | ola
# Processing Record 50 of Set 9 | srednekolymsk
# Processing Record 1 of Set 10 | ponta delgada
# Processing Record 2 of Set 10 | kapoeta
# Processing Record 3 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 4 of Set 10 | kumi
# Processing Record 5 of Set 10 | gigmoto
# Processing Record 6 of Set 10 | limanowa
# Processing Record 7 of Set 10 | morondava
# Processing Record 8 of Set 10 | sola
# Processing Record 9 of Set 10 | owensboro
# Processing Record 10 of Set 10 | peniche
# Processing Record 11 of Set 10 | ruwi
# Processing Record 12 of Set 10 | ranong
# Processing Record 13 of Set 10 | rundu
# Processing Record 14 of Set 10 | kjustendil
# Processing Record 15 of Set 10 | warwick
# Processing Record 16 of Set 10 | lakes entrance
# Processing Record 17 of Set 10 | kieta
# Processing Record 18 of Set 10 | miri
# Processing Record 19 of Set 10 | nisia floresta
# Processing Record 20 of Set 10 | melekhovo
# Processing Record 21 of Set 10 | mandalgovi
# Processing Record 22 of Set 10 | areia branca
# Processing Record 23 of Set 10 | bria
# Processing Record 24 of Set 10 | richards bay
# Processing Record 25 of Set 10 | gatton
# Processing Record 26 of Set 10 | grindavik
# Processing Record 27 of Set 10 | hasaki
# Processing Record 28 of Set 10 | udachnyy
# Processing Record 29 of Set 10 | odweyne
# Processing Record 30 of Set 10 | kampong chhnang
# Processing Record 31 of Set 10 | san vicente de canete
# Processing Record 32 of Set 10 | naryan-mar
# Processing Record 33 of Set 10 | acapulco
# Processing Record 34 of Set 10 | paracuru
# Processing Record 35 of Set 10 | foam lake
# Processing Record 36 of Set 10 | polewali
# Processing Record 37 of Set 10 | koboldo
# City not found. Skipping...
# Processing Record 38 of Set 10 | juneau
# Processing Record 39 of Set 10 | alamos
# Processing Record 40 of Set 10 | zhuanghe
# Processing Record 41 of Set 10 | midland
# Processing Record 42 of Set 10 | les cayes
# Processing Record 43 of Set 10 | shimoda
# Processing Record 44 of Set 10 | matamoros
# Processing Record 45 of Set 10 | kabinda
# Processing Record 46 of Set 10 | noumea
# Processing Record 47 of Set 10 | provideniya
# Processing Record 48 of Set 10 | leh
# Processing Record 49 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 10 | wuwei
# Processing Record 1 of Set 11 | los llanos de aridane
# Processing Record 2 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 11 | inta
# Processing Record 4 of Set 11 | alappuzha
# Processing Record 5 of Set 11 | baherden
# Processing Record 6 of Set 11 | ngerengere
# Processing Record 7 of Set 11 | saint george
# Processing Record 8 of Set 11 | almeria
# Processing Record 9 of Set 11 | clarence town
# Processing Record 10 of Set 11 | ketchikan
# Processing Record 11 of Set 11 | porosozero
# Processing Record 12 of Set 11 | mayna
# Processing Record 13 of Set 11 | plettenberg bay
# Processing Record 14 of Set 11 | winneba
# Processing Record 15 of Set 11 | dalvik
# Processing Record 16 of Set 11 | bam
# Processing Record 17 of Set 11 | pangkalanbuun
# Processing Record 18 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 11 | road town
# Processing Record 20 of Set 11 | baruun-urt
# Processing Record 21 of Set 11 | greymouth
# Processing Record 22 of Set 11 | zhigalovo
# Processing Record 23 of Set 11 | saint anthony
# Processing Record 24 of Set 11 | mapiri
# Processing Record 25 of Set 11 | sorong
# Processing Record 26 of Set 11 | ivaipora
# Processing Record 27 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 11 | tingrela
# City not found. Skipping...
# Processing Record 29 of Set 11 | santiago
# Processing Record 30 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 31 of Set 11 | cap malheureux
# Processing Record 32 of Set 11 | bochum
# Processing Record 33 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 11 | tomatlan
# Processing Record 35 of Set 11 | evanston
# Processing Record 36 of Set 11 | kidodi
# Processing Record 37 of Set 11 | vestmanna
# Processing Record 38 of Set 11 | suluq
# Processing Record 39 of Set 11 | coquimbo
# Processing Record 40 of Set 11 | roma
# Processing Record 41 of Set 11 | myitkyina
# Processing Record 42 of Set 11 | maamba
# Processing Record 43 of Set 11 | nome
# Processing Record 44 of Set 11 | savannakhet
# Processing Record 45 of Set 11 | pozoblanco
# Processing Record 46 of Set 11 | kodinar
# Processing Record 47 of Set 11 | pontianak
# Processing Record 48 of Set 11 | le moule
# Processing Record 49 of Set 11 | hobyo
# Processing Record 50 of Set 11 | krasnovishersk
# Processing Record 1 of Set 12 | wamba
# Processing Record 2 of Set 12 | mulege
# Processing Record 3 of Set 12 | vikhorevka
# Processing Record 4 of Set 12 | lancaster
# Processing Record 5 of Set 12 | otaru
# Processing Record 6 of Set 12 | eureka
# Processing Record 7 of Set 12 | luau
# Processing Record 8 of Set 12 | chateauroux
# Processing Record 9 of Set 12 | san quintin
# Processing Record 10 of Set 12 | samoded
# Processing Record 11 of Set 12 | grand-santi
# Processing Record 12 of Set 12 | wewak
# Processing Record 13 of Set 12 | emerald
# Processing Record 14 of Set 12 | whitianga
# Processing Record 15 of Set 12 | bakel
# Processing Record 16 of Set 12 | calbuco
# Processing Record 17 of Set 12 | glencoe
# Processing Record 18 of Set 12 | voi
# Processing Record 19 of Set 12 | ixtapa
# Processing Record 20 of Set 12 | san cristobal
# Processing Record 21 of Set 12 | zlutice
# Processing Record 22 of Set 12 | balsas
# Processing Record 23 of Set 12 | san fernando
# Processing Record 24 of Set 12 | coihaique
# Processing Record 25 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 12 | kalaiya
# Processing Record 27 of Set 12 | mokrous
# Processing Record 28 of Set 12 | ashland
# Processing Record 29 of Set 12 | nara
# Processing Record 30 of Set 12 | chalus
# Processing Record 31 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 12 | lakatoro
# Processing Record 33 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 12 | cockburn town
# Processing Record 35 of Set 12 | sulangan
# Processing Record 36 of Set 12 | boa vista
# Processing Record 37 of Set 12 | beloha
# Processing Record 38 of Set 12 | araouane
# Processing Record 39 of Set 12 | kilindoni
# Processing Record 40 of Set 12 | deputatskiy
# Processing Record 41 of Set 12 | melo
# Processing Record 42 of Set 12 | saint-louis
# Processing Record 43 of Set 12 | castanos
# Processing Record 44 of Set 12 | kerikeri
# Processing Record 45 of Set 12 | botoroaga
# Processing Record 46 of Set 12 | kimbe
# Processing Record 47 of Set 12 | ust-kuyga
# Processing Record 48 of Set 12 | deqing
# Processing Record 49 of Set 12 | san juan
# Processing Record 50 of Set 12 | rafsanjan
# Processing Record 1 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 2 of Set 13 | synya
# Processing Record 3 of Set 13 | linjiang
# Processing Record 4 of Set 13 | abu zabad
# Processing Record 5 of Set 13 | ampanihy
# Processing Record 6 of Set 13 | gobabis
# Processing Record 7 of Set 13 | darlowo
# Processing Record 8 of Set 13 | vila franca do campo
# Processing Record 9 of Set 13 | wolow
# Processing Record 10 of Set 13 | rocha
# Processing Record 11 of Set 13 | ambilobe
# Processing Record 12 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 14 of Set 13 | borogontsy
# Processing Record 15 of Set 13 | vangaindrano
# Processing Record 16 of Set 13 | vilhena
# Processing Record 17 of Set 13 | laguna
# Processing Record 18 of Set 13 | zastron
# Processing Record 19 of Set 13 | lixourion
# Processing Record 20 of Set 13 | houma
# Processing Record 21 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 13 | molodizhne
# Processing Record 23 of Set 13 | leshukonskoye
# Processing Record 24 of Set 13 | mwinilunga
# Processing Record 25 of Set 13 | neryungri
# Processing Record 26 of Set 13 | morozovsk
# Processing Record 27 of Set 13 | siare
# City not found. Skipping...
# Processing Record 28 of Set 13 | iralaya
# Processing Record 29 of Set 13 | goderich
# Processing Record 30 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | norfolk
# Processing Record 32 of Set 13 | tiznit
# Processing Record 33 of Set 13 | abilene
# Processing Record 34 of Set 13 | ouahigouya
# Processing Record 35 of Set 13 | lomza
# Processing Record 36 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 13 | arlit
# Processing Record 38 of Set 13 | tamworth
# Processing Record 39 of Set 13 | nagyrabe
# Processing Record 40 of Set 13 | scicli
# Processing Record 41 of Set 13 | russellville
# Processing Record 42 of Set 13 | delta
# Processing Record 43 of Set 13 | kawhia
# Processing Record 44 of Set 13 | bandar-e lengeh
# Processing Record 45 of Set 13 | yenagoa
# Processing Record 46 of Set 13 | hastings
# Processing Record 47 of Set 13 | chapleau
# Processing Record 48 of Set 13 | saint-georges
# Processing Record 49 of Set 13 | xining
# Processing Record 50 of Set 13 | glendive
# Processing Record 1 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | buraydah
# Processing Record 3 of Set 14 | vanimo
# Processing Record 4 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 14 | innisfail
# Processing Record 6 of Set 14 | belmonte
# Processing Record 7 of Set 14 | samarai
# Processing Record 8 of Set 14 | lusambo
# Processing Record 9 of Set 14 | rakkestad
# Processing Record 10 of Set 14 | paciran
# Processing Record 11 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 14 | waipawa
# Processing Record 13 of Set 14 | mathbaria
# Processing Record 14 of Set 14 | minas
# Processing Record 15 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 14 | lasa
# Processing Record 17 of Set 14 | ocos
# Processing Record 18 of Set 14 | londoko
# Processing Record 19 of Set 14 | ambovombe
# Processing Record 20 of Set 14 | tianpeng
# Processing Record 21 of Set 14 | byron bay
# Processing Record 22 of Set 14 | enid
# Processing Record 23 of Set 14 | kurchum
# Processing Record 24 of Set 14 | rawson
# Processing Record 25 of Set 14 | rio grande
# Processing Record 26 of Set 14 | shieli
# Processing Record 27 of Set 14 | phuket
# Processing Record 28 of Set 14 | yaransk
# Processing Record 29 of Set 14 | mahajanga
# Processing Record 30 of Set 14 | grand gaube
# Processing Record 31 of Set 14 | berdigestyakh
# Processing Record 32 of Set 14 | naze
# Processing Record 33 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 14 | kholodnyy
# Processing Record 35 of Set 14 | dzan
# Processing Record 36 of Set 14 | paoua
# Processing Record 37 of Set 14 | gidole
# Processing Record 38 of Set 14 | sakaraha
# Processing Record 39 of Set 14 | davidson
# Processing Record 40 of Set 14 | ust-nera
# Processing Record 41 of Set 14 | axim
# Processing Record 42 of Set 14 | nelidovo
# Processing Record 43 of Set 14 | mvomero
# Processing Record 44 of Set 14 | omboue
# Processing Record 45 of Set 14 | manaure
# Processing Record 46 of Set 14 | kirensk
# Processing Record 47 of Set 14 | aykhal
# Processing Record 48 of Set 14 | ternovskaya
# Processing Record 49 of Set 14 | salalah
# Processing Record 50 of Set 14 | urusha
# Processing Record 1 of Set 15 | tabou
# Processing Record 2 of Set 15 | lukovetskiy
# Processing Record 3 of Set 15 | lugovoy
# Processing Record 4 of Set 15 | fortuna
# Processing Record 5 of Set 15 | waddan
# Processing Record 6 of Set 15 | kindu
# Processing Record 7 of Set 15 | suzhou
# Processing Record 8 of Set 15 | agadir
# Processing Record 9 of Set 15 | haizhou
# Processing Record 10 of Set 15 | jibuti
# Processing Record 11 of Set 15 | mountain home
# Processing Record 12 of Set 15 | vao
# Processing Record 13 of Set 15 | chandler
# Processing Record 14 of Set 15 | katha
# City not found. Skipping...
# Processing Record 15 of Set 15 | madimba
# Processing Record 16 of Set 15 | alpena
# Processing Record 17 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 15 | mugur-aksy
# Processing Record 19 of Set 15 | tromso
# Processing Record 20 of Set 15 | mahibadhoo
# Processing Record 21 of Set 15 | honolulu
# Processing Record 22 of Set 15 | palmer
# Processing Record 23 of Set 15 | rantauprapat
# Processing Record 24 of Set 15 | elko
# Processing Record 25 of Set 15 | hofn
# Processing Record 26 of Set 15 | victor harbor
# Processing Record 27 of Set 15 | namtsy
# Processing Record 28 of Set 15 | dauphin
# Processing Record 29 of Set 15 | along
# Processing Record 30 of Set 15 | lisakovsk
# Processing Record 31 of Set 15 | bud
# Processing Record 32 of Set 15 | kribi
# Processing Record 33 of Set 15 | mullingar
# Processing Record 34 of Set 15 | christchurch
# Processing Record 35 of Set 15 | abingdon
# Processing Record 36 of Set 15 | mae ramat
# Processing Record 37 of Set 15 | kloulklubed
# Processing Record 38 of Set 15 | zherdevka
# Processing Record 39 of Set 15 | shingu
# Processing Record 40 of Set 15 | rafaela
# Processing Record 41 of Set 15 | moyo
# Processing Record 42 of Set 15 | neiafu
# Processing Record 43 of Set 15 | kayes
# Processing Record 44 of Set 15 | paamiut
# Processing Record 45 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 15 | harnai
# Processing Record 47 of Set 15 | portland
# Processing Record 48 of Set 15 | lokachi
# Processing Record 49 of Set 15 | kalemie
# Processing Record 50 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 16 | camapua
# Processing Record 2 of Set 16 | tymovskoye
# Processing Record 3 of Set 16 | waingapu
# Processing Record 4 of Set 16 | forest
# Processing Record 5 of Set 16 | manoel urbano
# Processing Record 6 of Set 16 | vilyuysk
# Processing Record 7 of Set 16 | dzhalil
# Processing Record 8 of Set 16 | aracati
# Processing Record 9 of Set 16 | natitingou
# Processing Record 10 of Set 16 | abu kamal
# Processing Record 11 of Set 16 | cururupu
# Processing Record 12 of Set 16 | manbij
# Processing Record 13 of Set 16 | altusried
# Processing Record 14 of Set 16 | tanabe
# Processing Record 15 of Set 16 | bucak
# Processing Record 16 of Set 16 | syava
# Processing Record 17 of Set 16 | svetlyy
# Processing Record 18 of Set 16 | gamba
# Processing Record 19 of Set 16 | central point
# Processing Record 20 of Set 16 | salina cruz
# Processing Record 21 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 16 | panitian
# Processing Record 23 of Set 16 | high level
# Processing Record 24 of Set 16 | pangody
# Processing Record 25 of Set 16 | wallaceburg
# Processing Record 26 of Set 16 | moerai
# Processing Record 27 of Set 16 | matara
# Processing Record 28 of Set 16 | paita
# Processing Record 29 of Set 16 | hoover
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Lorengau  -2.0226  147.2712     82.11        80          85
# 1     Nantucket  41.2835  -70.0995     41.40        53           0
# 2   Port Alfred -33.5906   26.8910     60.22        81           0
# 3        Torbay  47.6666  -52.7314     37.99       100          90
# 4        Urumqi  43.8010   87.6005     42.80        61           0
# 5     Saskylakh  71.9167  114.0833     -9.92        93          16
# 6        Najran  17.4924   44.1277     68.00        21          19
# 7  Port Moresby  -9.4431  147.1797     93.20        49          75
# 8  Ponta Do Sol  32.6667  -17.1000     57.00        66          61
# 9        Atuona  -9.8000 -139.0333     80.74        74         100
#
#    Wind Speed Country Current Description                 Date
# 0       10.83      PG          light rain  2021-04-04 02:34:24
# 1       11.59      US           clear sky  2021-04-04 02:34:24
# 2        8.66      ZA           clear sky  2021-04-04 02:34:25
# 3       12.66      CA          light rain  2021-04-04 02:34:25
# 4        4.47      CN           clear sky  2021-04-04 02:34:25
# 5        2.44      RU          few clouds  2021-04-04 02:34:26
# 6       16.11      SA                dust  2021-04-04 02:34:26
# 7       11.50      PG       broken clouds  2021-04-04 02:32:56
# 8        1.01      PT       broken clouds  2021-04-04 02:34:27
# 9       11.81      PF     overcast clouds  2021-04-04 02:30:54

# %%
# Re-arranged columns.
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed",
                   "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0       Lorengau      PG  2021-04-04 02:34:24  -2.0226  147.2712     82.11
# 1      Nantucket      US  2021-04-04 02:34:24  41.2835  -70.0995     41.40
# 2    Port Alfred      ZA  2021-04-04 02:34:25 -33.5906   26.8910     60.22
# 3         Torbay      CA  2021-04-04 02:34:25  47.6666  -52.7314     37.99
# 4         Urumqi      CN  2021-04-04 02:34:25  43.8010   87.6005     42.80
# ..           ...     ...                  ...      ...       ...       ...
# 711  Wallaceburg      CA  2021-04-04 02:38:02  42.5930  -82.3885     55.40
# 712       Moerai      PF  2021-04-04 02:38:02 -22.4333 -151.3333     79.66
# 713       Matara      LK  2021-04-04 02:38:03   5.9485   80.5353     83.07
# 714        Paita      PE  2021-04-04 02:38:03  -5.0892  -81.1144     72.52
# 715       Hoover      US  2021-04-04 02:38:03  33.4054  -86.8114     53.60
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          80          85       10.83          light rain
# 1          53           0       11.59           clear sky
# 2          81           0        8.66           clear sky
# 3         100          90       12.66          light rain
# 4          61           0        4.47           clear sky
# ..        ...         ...         ...                 ...
# 711        37           1        6.85           clear sky
# 712        66          11       14.07          few clouds
# 713        69          16        9.26          few clouds
# 714        78          86        4.85     overcast clouds
# 715        40           1        1.99           clear sky
#
# [716 rows x 10 columns]

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
